# %% [markdown]
# <a href="https://colab.research.google.com/github/leticiavasconcelos1/logicaprogramacaophyton/blob/main/logicaprogramacaophyton/exerciciosfluxograma/Lista_de_exercicios_Testemesa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #média entre duas notas
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %%
#entrada
p1 = float(input(" Digite a primeira nota de 0 à 10: "))
p2 = float(input(" Digite a segunda nota de 0 à 10: "))

#processamento

m = (p1+p2)/2

#saida

print(" A média entre suas notas é: ",m)

# %% [markdown]
# # dolar
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
dl= float(input(" qual o valor do dolar: "))
reais= float(input(" qual o valor que deve ser convertido: "))

#processamento
conversao= reais/dl

#saida
print(" o valor é: ", conversao)
# Out:
#  qual o valor do dolar: 5.06
#  qual o valor que deve ser convertido: 50
#  o valor é:  9.881422924901187

# %% [markdown]
# ## soma dos quadrados
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# entrada
n1= float(input(" digite o primeiro número "))
n2= float(input(" digite o segundo número "))
n3= float(input(" digite o terceiro número "))
n4= float(input(" digite o ultimo número "))

#processamneto

qn1= n1*n1
qn2= n2*n2
qn3= n3*n3
qn4= n4*n4

#processamento

total= qn1+qn2+qn3+qn4

#saida

print("o total da soma é: ", total)
# Out:
#  digite o primeiro número 5
#  digite o segundo número 8
#  digite o terceiro número 7
#  digite o ultimo número 6
# o total da soma é:  174.0

# %% [markdown]
# ## pagamento de comissão
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# entrada

pp= float(input(" qual o valor de cada peça? "))
qv= float(input(" quantas peças foram vendidas? "))

#processamento

comi=(pp*qv)/100*(5)

#saida

print(" a sua comissão será: ",comi)
# Out:
#  qual o valor de cada peça? 5.0
#  quantas peças foram vendidas? 25
#  a sua comissão será:  6.25

# %% [markdown]
# ## custo carro novo
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada
cfc= float(input(" digite o custo de fabrica do carro:  "))

#processamento
I= (cfc)+( 45*cfc)/100
D= (28*I)/100

#saida
print(" o custo do carro sera de: ",I+D)
# Out:
#  digite o custo de fabrica do carro:  25.000
#  o custo do carro sera de:  46.4

# %% [markdown]
# ## minutos e horas em segundos
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# entrada
h= float(input(" quais são as horas? "))
min= float(input(" quais são os minutos? "))

#processamento

mt= min/60
res= mt+h

#saida

print(" o seu valor em segundos é: ", res)
# Out:
#  quais são as horas? 7
#  quais são os minutos? 0
#  o seu valor em segundos é:  7.0

# %% [markdown]
# ## hora extra
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# entrada
h= float(input(" quais são as horas? "))
min= float(input(" quais são os minutos? "))
vh= float(input(" qual é o valor recebido por hora? "))
#processamento

mt= min/60
res= mt+h

#processamento
sal= res*vh
he=(sal*70/100)+sal

#saida

print("sua hora extra é de: ", he)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-752ba39c4bd8> in <cell line: 2>()
#       1 # entrada
# ----> 2 h= float(input(" quais são as horas? "))
#       3 min= float(input(" quais são os minutos? "))
#       4 vh= float(input(" qual é o valor recebido por hora? "))
#       5 #processamento
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %% [markdown]
# ##gasto de gasolina
# ![image.png](data:image/png;base64,...)

# %%
#entrada
kmp= float(input(" quantos quilometros ira percorrer? "))
gc= float(input(" quantos quilometros seu carro percorre por litro? "))
pmg= float(input(" qual o preço médio da gasolina? "))

#processamento

resul= (kmp/gc)*pmg

#saida

print(" você gastará $: ", resul)
# Out:
#  quantos quilometros ira percorrer? 1000
#  quantos quilometros seu carro percorre por litro? 8
#  qual o preço médio da gasolina? 5
#  você gastará $:  625.0

# %% [markdown]
# ##multa por velocidade média
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
#entrada

pp= float(input(" qual é a distancia percorrida? "))
tg= float(input(" qual foi o tempo gasto no percurso? "))

#processamneto

vm= pp/tg

#saida

print(f" sua velocidade média é de: {vm:.2f} ")
# Out:
#  qual é a distancia percorrida? 500
#  qual foi o tempo gasto no percurso? 4.5
#  sua velocidade média é de: 111.11
